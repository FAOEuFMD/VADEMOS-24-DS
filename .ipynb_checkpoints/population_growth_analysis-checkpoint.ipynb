# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pmdarima import auto_arima
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error, mean_squared_error
import random
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # Population growth estimation

# %% [markdown]
# # 1. Exploratory Data Analysis

# %%
# Reading a CSV file
df = pd.read_csv('data/FAOSTAT_animal_2022.csv')

df.dtypes
# Out:
# Domain Code          object
# Domain               object
# Area Code (M49)       int64
# Area                 object
# Element Code          int64
# Element              object
# Item Code (CPC)     float64
# Item                 object
# Year Code             int64
# Year                  int64
# Unit                 object
# Value                 int64
# Flag                 object
# Flag Description     object
# Note                 object
# dtype: object

# %% [markdown]
# Let's explore the origin of the population data, to see how many official figures we have vs estimated values per country and in total

# %%
df.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)         Area  \
# 0         QCL  Crops and livestock products                4  Afghanistan
# 1         QCL  Crops and livestock products                4  Afghanistan
# 2         QCL  Crops and livestock products                4  Afghanistan
# 3         QCL  Crops and livestock products                4  Afghanistan
# 4         QCL  Crops and livestock products                4  Afghanistan
#
#    Element Code Element  Item Code (CPC)   Item  Year Code  Year Unit  \
# 0          5111  Stocks           2132.0  Asses       1961  1961   An
# 1          5111  Stocks           2132.0  Asses       1962  1962   An
# 2          5111  Stocks           2132.0  Asses       1963  1963   An
# 3          5111  Stocks           2132.0  Asses       1964  1964   An
# 4          5111  Stocks           2132.0  Asses       1965  1965   An
#
#      Value Flag Flag Description Note
# 0  1300000    A  Official figure  NaN
# 1   851850    A  Official figure  NaN
# 2  1001112    A  Official figure  NaN
# 3  1150000    E  Estimated value  NaN
# 4  1300000    A  Official figure  NaN

# %% [markdown]
# ### 1.1 Which type of animals are included in our dataset?

# %% [markdown]
# Since the diseases we are studying don't affect winged (bird) animals, we are removing them from the modelling data.

# %%
# Explore the actual animals we have values for
unique_values = df['Item'].unique()
print("We have the following animals with population counted:")
print(unique_values)

# Define the list of animals for analysis
animals_for_analysis = ['Asses', 'Camels', 'Cattle', 'Goats', 'Horses', 'Sheep', 'Buffalo', 'Swine / pigs', 'Other camelids']

# Filter the DataFrame to include only the selected animals
df = df[df['Item'].isin(animals_for_analysis)]
unique_values = df['Item'].unique()
print("After filtering winged animals we have the following animals with population counted:")
print(unique_values)
# Out:
# We have the following animals with population counted:
# ['Asses' 'Camels' 'Cattle' 'Goats' 'Horses' 'Sheep' 'Buffalo'
#  'Swine / pigs' 'Other camelids']
# After filtering winged animals we have the following animals with population counted:
# ['Asses' 'Camels' 'Cattle' 'Goats' 'Horses' 'Sheep' 'Buffalo'
#  'Swine / pigs' 'Other camelids']

# %% [markdown]
# ### 1.2 How many years are available

# %%
# Explore the actual animals we have values for
unique_values = df['Year'].unique()
print("We have the following years:")
print(unique_values)
# Out:
# We have the following years:
# [1961 1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974
#  1975 1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988
#  1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002
#  2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016
#  2017 2018 2019 2020 2021 2022]

# %% [markdown]
# ### 1.3  Origin of the population value
#
# Let's delve into the methodology behind obtaining population numbers across countries. These numbers are derived from various sources, including official figures, imputed values, and estimations from international organizations. By examining this data by country, we can assess its reliability.
#
# Here are some key insights we can draw:
#
# 1. The data has minimal missing values, averaging around 2%. However, the 75th percentile indicates that most countries have no missing data. Some countries (althought very few) have 54% missing data. Should we retain countries with a high percentage of missing data (e.g Palestine)  or is it advisable to exclude them?
# 2. A significant portion of the data, averaging at 33%, is labeled as "estimated value." What exactly does this mean? Does it suggest the use of modeling techniques for estimation?
# Approximately 54% of the data consists of "official figures."
# 3. Some countries exhibit entirely estimated values. Can we place confidence in such data? How should we handle countries with very low proportions of "official figure" values? And how might this affect the credibility of our model?
#
# By addressing these questions, we can better understand the robustness of our dataset and its implications for our analysis.

# %%
# Grouping by 'Area' and 'Flag Description' and counting the occurrences, 
flag_counts = df.groupby(["Area", "Flag Description"]).size().unstack(fill_value=0)

#Calculate the total count for each 'Area'
total_counts = flag_counts.sum(axis=1)

# Calculate the percentage of each 'Flag Description' for each 'Area'
percentage_counts = ((flag_counts.div(total_counts, axis=0))*100).round(2)
percentage_counts.describe()
# Out:
# Flag Description  Estimated value  Figure from international organizations  \
# count                  204.000000                               204.000000
# mean                    30.591716                                 3.299461
# std                     23.224364                                 5.095091
# min                      0.000000                                 0.000000
# 25%                     10.847500                                 0.000000
# 50%                     28.285000                                 1.115000
# 75%                     48.692500                                 4.667500
# max                     89.920000                                37.300000
#
# Flag Description  Imputed value  \
# count                204.000000
# mean                   5.516765
# std                    5.322429
# min                    0.000000
# 25%                    0.762500
# 50%                    4.340000
# 75%                    8.767500
# max                   37.100000
#
# Flag Description  Missing value (data cannot exist, not applicable)  \
# count                                                    204.000000
# mean                                                       1.480784
# std                                                        5.595817
# min                                                        0.000000
# 25%                                                        0.000000
# 50%                                                        0.000000
# 75%                                                        0.000000
# max                                                       53.230000
#
# Flag Description  Official figure
# count                  204.000000
# mean                    59.111078
# std                     28.490276
# min                      0.000000
# 25%                     34.207500
# 50%                     62.650000
# 75%                     84.007500
# max                    100.000000

# %% [markdown]
# ##### 1.3.1 Official figure by country

# %%
percentage_counts = percentage_counts.sort_values(by='Official figure')
percentage_counts = percentage_counts.reset_index()

# Plotting with Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data = percentage_counts, x = "Area", y = "Official figure")
plt.title('Percentage of Official Figures by Area')
plt.xlabel('Area')
plt.ylabel('Percentage of Official Figures (%)')


# Selecting every 10th tick for display
x_ticks = percentage_counts.index[::3].tolist()
x_ticklabels = percentage_counts['Area'].iloc[::3].tolist()

# Set xticks and xticklabels
plt.xticks(x_ticks, x_ticklabels, rotation=90, ha='right')
plt.tight_layout()

# %% [markdown]
# ##### 1.3.2 Estimated figure by country

# %%
# sort by estimated value
percentage_counts = percentage_counts.sort_values(by='Estimated value')
percentage_counts = percentage_counts.reset_index()

# Plotting with Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data = percentage_counts, x = "Area", y = "Estimated value")
plt.title('Percentage of Estimated value  by Area')
plt.xlabel('Area')
plt.ylabel('Percentage of Estimated value Figures (%)')

# Selecting every 10th tick for display
x_ticks = percentage_counts.index[::3].tolist()
x_ticklabels = percentage_counts['Area'].iloc[::3].tolist()

# Set xticks and xticklabels
plt.xticks(x_ticks, x_ticklabels, rotation=90, ha='right')
plt.tight_layout()

# %% [markdown]
# ##### 1.3.3 Missing values by country

# %%
# sort by estimated value
percentage_counts = percentage_counts.sort_values(by='Missing value (data cannot exist, not applicable)')
percentage_counts = percentage_counts.reset_index()

# Plotting with Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data = percentage_counts, x = "Area", y = "Missing value (data cannot exist, not applicable)")
plt.title('Percentage of Estimated value  by Area')
plt.xlabel('Area')
plt.ylabel('Percentage of Estimated value Figures (%)')

# Selecting every 10th tick for display
x_ticks = percentage_counts.index[::3].tolist()
x_ticklabels = percentage_counts['Area'].iloc[::3].tolist()

# Set xticks and xticklabels
plt.xticks(x_ticks, x_ticklabels, rotation=90, ha='right')
plt.tight_layout()

# %%
percentage_counts.tail(20)
# Out:
# Flag Description  level_0  index  \
# 188                    69    124
# 189                    96     93
# 190                    30    168
# 191                    23    174
# 192                    35    135
# 193                   138     61
# 194                    61    133
# 195                   173     38
# 196                    95     94
# 197                    98     87
# 198                   171     33
# 199                   153     53
# 200                    22    164
# 201                    19    156
# 202                   106     76
# 203                    58    121
# 204                   102     52
# 205                   158     28
# 206                    89     35
# 207                    28     41
#
# Flag Description                                               Area  \
# 188                                                         Ukraine
# 189                                      Iran (Islamic Republic of)
# 190                                                        Mongolia
# 191                                                      Montenegro
# 192                                                         Ireland
# 193                                                         Namibia
# 194               United Kingdom of Great Britain and Northern I...
# 195                                                    Sierra Leone
# 196                                               Brunei Darussalam
# 197                                        Central African Republic
# 198                                                         Bahamas
# 199                                                         Bahrain
# 200                                                          Poland
# 201                                                         Germany
# 202                                                       Australia
# 203                                Democratic Republic of the Congo
# 204                                                          Tuvalu
# 205                                                       Singapore
# 206                                                     South Sudan
# 207                                                       Palestine
#
# Flag Description  Estimated value  Figure from international organizations  \
# 188                         15.67                                     0.46
# 189                         25.60                                     4.03
# 190                          5.07                                     0.00
# 191                          3.53                                     0.00
# 192                          6.27                                     8.45
# 193                         36.64                                     2.53
# 194                         12.58                                     0.65
# 195                         55.16                                     0.97
# 196                         24.52                                     6.45
# 197                         26.77                                     1.29
# 198                         53.87                                     0.32
# 199                         45.48                                     4.84
# 200                          3.49                                     0.00
# 201                          2.45                                     0.00
# 202                         29.26                                     0.69
# 203                         12.10                                     0.00
# 204                         28.23                                     0.00
# 205                         48.79                                     0.00
# 206                         21.21                                     0.00
# 207                          4.30                                     3.76
#
# Flag Description  Imputed value  \
# 188                        7.37
# 189                        6.25
# 190                        0.00
# 191                        0.00
# 192                        0.27
# 193                        8.53
# 194                        1.29
# 195                        6.45
# 196                        1.61
# 197                        5.81
# 198                       10.32
# 199                        2.90
# 200                        0.00
# 201                        0.27
# 202                        4.38
# 203                        2.15
# 204                       12.10
# 205                        3.23
# 206                       18.18
# 207                        8.06
#
# Flag Description  Missing value (data cannot exist, not applicable)  \
# 188                                                            5.07
# 189                                                            6.05
# 190                                                            6.45
# 191                                                            7.06
# 192                                                            8.17
# 193                                                            8.99
# 194                                                            9.35
# 195                                                            9.35
# 196                                                            9.35
# 197                                                            9.68
# 198                                                            9.68
# 199                                                            9.68
# 200                                                            9.84
# 201                                                           13.35
# 202                                                           14.29
# 203                                                           16.13
# 204                                                           24.19
# 205                                                           25.40
# 206                                                           33.33
# 207                                                           53.23
#
# Flag Description  Official figure
# 188                         71.43
# 189                         58.06
# 190                         88.48
# 191                         89.41
# 192                         76.84
# 193                         43.32
# 194                         76.13
# 195                         28.06
# 196                         58.06
# 197                         56.45
# 198                         25.81
# 199                         37.10
# 200                         86.67
# 201                         83.92
# 202                         51.38
# 203                         69.62
# 204                         35.48
# 205                         22.58
# 206                         27.27
# 207                         30.65

# %% [markdown]
# ##### 1.3.4 Investigate years of data available
# For running certain models the number of year points available would be critical for model performance, we can see we have 62 points of data available. The majority of the countries are above 58 datapoints and 25% of countries-animal may be below this. We can see that 10% of the countries-animal have less data points than 31

# %%
def count_years_of_data(df):
    """
    Count the number of years of data available for each country and animal type.

    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame containing the time series data with columns 'Year', 'Area', 'Item', and 'Value'.

    Returns:
    --------
    pandas.DataFrame
        DataFrame containing the counts of years of data available for each country and animal type.
    """
    # Group by country and animal type, then count the unique years
    years_count = df.groupby(['Area', 'Item'])['Year'].nunique().reset_index()

    # Rename the columns for clarity
    years_count.columns = ['Country', 'AnimalType', 'YearsOfData']

    return years_count

years_data_count = count_years_of_data(df)
years_data_count.describe()

# Compute the 10th percentile
percentile_10 = years_data_count['YearsOfData'].quantile(0.1)

# Create the DataFrame description
description_with_percentile = years_data_count.describe()
# Add the 10th percentile to the DataFrame's description
description_with_percentile.loc['10th Percentile'] = percentile_10

description_with_percentile
# Out:
#                  YearsOfData
# count            1180.000000
# mean               55.144068
# std                14.333408
# min                 1.000000
# 25%                62.000000
# 50%                62.000000
# 75%                62.000000
# max                62.000000
# 10th Percentile    31.000000

# %%
# Recoding the country names as per R code

# Dictionary for recoding the values
recode_dict = {
    "Cabo Verde": "Cape Verde", 
    "UAE": "United Arab Emirates", 
    "Syria": "Syrian Arab Republic", 
    "DRC": "Democratic Republic of the Congo",
    "Namibia (zone)": "Namibia", 
    "Sao Tome et Principe": "Sao Tome and Principe", 
    "Guinea Bissau": "Guinea-Bissau", 
    "Iran": "Iran (Islamic Republic of)",
    "Tanzania": "United Republic of Tanzania",
    "Côte d'Ivoire": "Ivory Coast",
    "Belgium-Luxembourg": "Belgium", 
    "China, mainland": "China",
    "United Kingdom of Great Britain and Northern Ireland": "United Kingdom", 
    "Sudan (former)": "Sudan", 
    "Ethiopia PDR": "Ethiopia", 
    "Myanmar": "Burma"
}

df['Area'] = df['Area'].replace(recode_dict)
df['Area'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cape Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'China, Hong Kong SAR', 'China, Taiwan Province of', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Ivory Coast',
#        'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Czechoslovakia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Faroe Islands', 'Fiji', 'Finland',
#        'France', 'French Guiana', 'French Polynesia', 'Gabon', 'Gambia',
#        'Georgia', 'Germany', 'Ghana', 'Greece', 'Grenada', 'Guadeloupe',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran (Islamic Republic of)', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic",
#        'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Lithuania',
#        'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Mali', 'Malta',
#        'Martinique', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (Federated States of)', 'Mongolia', 'Montenegro',
#        'Morocco', 'Mozambique', 'Burma', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands (Kingdom of the)', 'New Caledonia', 'New Zealand',
#        'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'North Macedonia',
#        'Norway', 'Oman', 'Pakistan', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Puerto Rico', 'Qatar', 'Republic of Korea',
#        'Republic of Moldova', 'Réunion', 'Romania', 'Russian Federation',
#        'Rwanda', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Samoa',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Serbia and Montenegro', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia',
#        'South Africa', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syrian Arab Republic',
#        'Tajikistan', 'Thailand', 'Timor-Leste', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Türkiye',
#        'Turkmenistan', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom',
#        'United Republic of Tanzania', 'United States of America',
#        'Uruguay', 'USSR', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Yemen',
#        'Yugoslav SFR', 'Zambia', 'Zimbabwe'], dtype=object)

# %% [markdown]
# # 2. Exploratory Data Analysis
#
# The following models will be explored
# ###  Exponential Smoothing Methods:
#
# Holt-Winters Exponential Smoothing: Suitable for data with trend and seasonality. It can provide reliable forecasts and is capable of handling extrapolation well.
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/
#
#
# ### Machine Learning Algorithms:
# - Gradient Boosting Machines (GBM): GBM algorithms, such as XGBoost or LightGBM, are powerful for forecasting tasks. They can capture complex patterns and handle extrapolation effectively.
# - Long Short-Term Memory (LSTM) Networks: LSTM networks are a type of recurrent neural network (RNN) designed for sequence prediction tasks like time series forecasting. They can capture long-term dependencies and are suitable for extrapolation.
# -
#
# ### Hybrid Models:
#
# - ARIMA with Machine Learning Models: Combine ARIMA with machine learning models to leverage the strengths of both approaches. For example, use ARIMA to model the trend and seasonality and then use a machine learning model to capture residual patterns and improve forecasting accuracy.
# - Ensemble Methods: Combine forecasts from multiple models, such as ARIMA, machine learning models, and exponential smoothing methods, to create a more robust and accurate forecast.
#
# ###  Facebook profet method
#  Prophet is a popular open-source library designed for forecasting time series data with an emphasis on simplicity, flexibility, and automatic handling of common time series issues such as seasonality, holidays, and missing data.
#  Prophet is particularly well-suited for forecasting tasks where the data exhibit strong seasonal patterns and multiple sources of uncertainty. It employs an additive model that decomposes the time series into trend, seasonality, and holiday components, allowing for more interpretable forecasts.

# %% [markdown]
# ### 2.1 ARIMA model
# ARIMA models capture the patterns and trends present in time series data by modeling the relationship between the variable of interest and its past values, past forecast errors, and differenced data to achieve stationarity
#
# In ARIMA, the autoregressive (AR) component models the relationship between the variable of interest and its past values, capturing the serial correlation in the data. The moving average (MA) component models the relationship between the current value and past forecast errors, capturing the random fluctuations in the data. The integration (I) component involves differencing the data to achieve stationarity, removing trends and seasonality.
#
# ARIMA(p, d, q)
# - p:  number of autoregesssive lags
# - q: number of moving average lags
# - d: order of differenciating
#
# We will use the auto_arima as it is
# Limitations:
# - ARIMA is sensitive to outliers and can be computationally intensive, especially for large datasets or high-order models.
# - ARIMA does not account for exogenous variables or external factors that may influence the time series, limiting its predictive capabilities in certain contexts
#       - Is there any other time series that could be incorporated to help model growth (e.g something related to the economy or number of natural disasters or something else???)
# - ARIMA doesn't account for seasonality of the data, maybe in our case it doesn't matter as we have yearly data rather than monthly so really no seasonality?
#
# Some assumptions:
# - It is assumed that in order to generate reliable ARIMA predictions we need at least 50 observations (so 50 years of data)
#   *** The recommendation of having at least 50 data points for ARIMA modeling is based on practical experience and rules of thumb in time series analysis rather than a strict theoretical minimum
#   *** Box-Jenkins Methodology: The foundational work by George Box and Gwilym Jenkins on ARIMA modeling, while not specifying a strict minimum, implies that more data points are generally better for reliable parameter estimation and model validation. The common practice derived from their work suggests having a reasonable amount of data, typically 50 or more observations.
# - If the time-series is constant and ARMA (0,0,0) model has been fitted
#
# Assumptions made for this analysis:
# - Eventhough it is recommended that the ARIMA model has at least 50 observations in order to run better, for this study only country-animal combinations with less that 20 years of data have been discarded.
# - To evaluate model performance the 95% CI has been used in the following way:
# - The percentage of datapoints outside the CI have been counted.
# - The number of models with >20% of values outside the CI have been counted
# - The number of models with >30% of values outside the CI have been counted
# - The combination of country - animal that met both requirements above (i.e outside 95% CI> 20% or > 30%) have been stored for future evaluation

# %% [markdown]
# #### 2.1.1 Sample size requirement for proper ARIMA estimation
#
# - As per bellow we have 46 occurrences bellow 20 datapoints
# - We also have 234 occurrences bellow 50 datapoints

# %%
# list and count the number of countries with less than 20 years of data
years_data_count_sorted = years_data_count.sort_values(by='YearsOfData', ascending=True)
number_of_countries_less_than20 = (years_data_count_sorted[years_data_count_sorted['YearsOfData']<20])['Country'].count()
number_of_countries_less_than20 = (years_data_count_sorted[years_data_count_sorted['YearsOfData']<20])['Country'].count()

print(f"The number of countries with less than 20 data points are {number_of_countries_less_than20}, and they are listed bellow")
(years_data_count_sorted[years_data_count_sorted['YearsOfData']<20])
# Out:
# The number of countries with less than 20 data points are 46, and they are listed bellow
#                            Country    AnimalType  YearsOfData
# 255                        Croatia       Buffalo            1
# 731   Netherlands (Kingdom of the)       Buffalo            1
# 298                        Denmark         Goats            2
# 1007                        Sweden         Goats            3
# 519                        Ireland       Buffalo            5
# 268                         Cyprus       Buffalo            5
# 622                      Lithuania       Buffalo            5
# 274                        Czechia       Buffalo            5
# 980                          Spain       Buffalo            5
# 1005                        Sweden       Buffalo            5
# 951                       Slovenia       Buffalo            5
# 345                        Estonia       Buffalo            5
# 945                       Slovakia       Buffalo            5
# 823                         Poland       Buffalo            5
# 593                         Latvia       Buffalo            5
# 660                          Malta       Buffalo            5
# 478                        Hungary       Buffalo            5
# 860                        Romania       Buffalo            5
# 628                     Luxembourg       Buffalo            5
# 830                       Portugal       Buffalo            5
# 296                        Denmark       Buffalo            5
# 371                        Finland       Buffalo            5
# 977                    South Sudan        Horses           11
# 976                    South Sudan         Goats           11
# 974                    South Sudan        Camels           11
# 973                    South Sudan         Asses           11
# 978                    South Sudan         Sheep           11
# 975                    South Sudan        Cattle           11
# 229                       Colombia       Buffalo           13
# 932          Serbia and Montenegro  Swine / pigs           14
# 931          Serbia and Montenegro         Sheep           14
# 928          Serbia and Montenegro        Cattle           14
# 930          Serbia and Montenegro        Horses           14
# 927          Serbia and Montenegro       Buffalo           14
# 929          Serbia and Montenegro         Goats           14
# 704                     Montenegro         Sheep           17
# 925                         Serbia         Sheep           17
# 923                         Serbia         Goats           17
# 702                     Montenegro         Goats           17
# 703                     Montenegro        Horses           17
# 705                     Montenegro  Swine / pigs           17
# 922                         Serbia        Cattle           17
# 926                         Serbia  Swine / pigs           17
# 701                     Montenegro        Cattle           17
# 924                         Serbia        Horses           17
# 91                         Belgium         Asses           18

# %%
# list and count the number of countries with less than 20 years of data
years_data_count_sorted = years_data_count.sort_values(by='YearsOfData', ascending=True)
number_of_countries_less_than20 = (years_data_count_sorted[years_data_count_sorted['YearsOfData']<50])['Country'].count()
number_of_countries_less_than20 = (years_data_count_sorted[years_data_count_sorted['YearsOfData']<50])['Country'].count()

print(f"The number of countries with less than 50 data points are {number_of_countries_less_than20}, and they are listed bellow")
(years_data_count_sorted[years_data_count_sorted['YearsOfData']<50]).head(60)
# Out:
# The number of countries with less than 50 data points are 234, and they are listed bellow
#                            Country    AnimalType  YearsOfData
# 255                        Croatia       Buffalo            1
# 731   Netherlands (Kingdom of the)       Buffalo            1
# 298                        Denmark         Goats            2
# 1007                        Sweden         Goats            3
# 519                        Ireland       Buffalo            5
# 268                         Cyprus       Buffalo            5
# 622                      Lithuania       Buffalo            5
# 274                        Czechia       Buffalo            5
# 980                          Spain       Buffalo            5
# 1005                        Sweden       Buffalo            5
# 951                       Slovenia       Buffalo            5
# 345                        Estonia       Buffalo            5
# 945                       Slovakia       Buffalo            5
# 823                         Poland       Buffalo            5
# 593                         Latvia       Buffalo            5
# 660                          Malta       Buffalo            5
# 478                        Hungary       Buffalo            5
# 860                        Romania       Buffalo            5
# 628                     Luxembourg       Buffalo            5
# 830                       Portugal       Buffalo            5
# 296                        Denmark       Buffalo            5
# 371                        Finland       Buffalo            5
# 977                    South Sudan        Horses           11
# 976                    South Sudan         Goats           11
# 974                    South Sudan        Camels           11
# 973                    South Sudan         Asses           11
# 978                    South Sudan         Sheep           11
# 975                    South Sudan        Cattle           11
# 229                       Colombia       Buffalo           13
# 932          Serbia and Montenegro  Swine / pigs           14
# 931          Serbia and Montenegro         Sheep           14
# 928          Serbia and Montenegro        Cattle           14
# 930          Serbia and Montenegro        Horses           14
# 927          Serbia and Montenegro       Buffalo           14
# 929          Serbia and Montenegro         Goats           14
# 704                     Montenegro         Sheep           17
# 925                         Serbia         Sheep           17
# 923                         Serbia         Goats           17
# 702                     Montenegro         Goats           17
# 703                     Montenegro        Horses           17
# 705                     Montenegro  Swine / pigs           17
# 922                         Serbia        Cattle           17
# 926                         Serbia  Swine / pigs           17
# 701                     Montenegro        Cattle           17
# 924                         Serbia        Horses           17
# 91                         Belgium         Asses           18
# 630                     Luxembourg         Goats           21
# 631                     Luxembourg        Horses           22
# 629                     Luxembourg        Cattle           23
# 633                     Luxembourg  Swine / pigs           23
# 632                     Luxembourg         Sheep           23
# 954                       Slovenia        Horses           26
# 254                        Croatia         Asses           26
# 348                        Estonia        Horses           27
# 258                        Croatia        Horses           27
# 948                       Slovakia        Horses           27
# 947                       Slovakia         Goats           28
# 277                        Czechia        Horses           30
# 278                        Czechia         Sheep           30
# 279                        Czechia  Swine / pigs           30

# %%
def fit_arima_model(df, country, animal_type, data_length = 20):
    """
    Fits an ARIMA or SARIMA model to the specified data.

    Parameters:
    df (pd.DataFrame): The data frame containing the time series data.
    country (str): The country for which the model is to be fitted.
    animal_type (str): The type of animal for which the model is to be fitted.
    data_length(int): The minimum number of samples to run the ARIMA model. Default is 20

    Returns:
    ARIMA: The fitted ARIMA model, or None if there is not enough data.
    """
    try:
        # Filter data for the specified animal and country
        data = df[(df['Area'] == country) & (df['Item'] == animal_type)]
        
        if not data.empty:
            # Convert year to index and grab only population value
            data = data.set_index('Year')['Value']
            
            # Drop missing values
            data = data.dropna()

            # Ensure data length is sufficient
            if len(data) < data_length: 
                print(f"Not enough data for {country} - {animal_type}")
                return None

            # Check if the series is constant
            if data.nunique() == 1:
                print(f"Time series for {country} - {animal_type} is constant. Fitting ARMA(0,0,0) model.")
                # Fit ARIMA(0,0,0) model
                arima_model = sm.tsa.arima.ARIMA(data, order=(0, 0, 0))
                arima_results = arima_model.fit()
                return arima_results


            # Fit ARIMA  model using auto_arima
            arima_model = auto_arima(data, seasonal=False)
            return arima_model

        else:
            #print(f"No data for {country} - {animal_type}")
            return None

    except ValueError as e:
        print(f"Error fitting ARIMA model for {country} - {animal_type}: {e}")
        return None

# %%
countries = df['Area'].unique()
animal_types = df['Item'].unique()

# %%
def evaluate_model(df, country, animal_type, test_start_year, confidence_level = 0.95):
    """
    Evaluate the ARIMA model for a specific country and animal type.

    Parameters:
    -----------
    df : pandas.DataFrame
        DataFrame containing the time series data with columns 'Year', 'Area', 'Item', and 'Value'.
    country : str
        The country for which the model is to be evaluated.
    animal_type : str
        The type of animal for which the model is to be evaluated.
    test_start_year : int
        The year from which the test data starts. Data before this year will be used for training, and data from this
        year onwards will be used for testing.
    confidence_level:float
        The confidence level for the prediction intervals. Default at 0.95

    Returns:
    --------
    tuple
        A tuple containing:
        - mae : float
            Mean Absolute Error of the model's predictions on the test set.
        - mse : float
            Mean Squared Error of the model's predictions on the test set.
        - test : pandas.Series
            The actual values of the test set.
        - predictions : numpy.ndarray
            The predicted values for the test set.
        - proportion_in_ci : float
            The proportion of actual values that fall within the confidence_level intervals of the predicted values


    Example:
    --------
    >>> evaluate_model(df, 'Afghanistan', 'Asses', 2015)
    MAE for Afghanistan - Asses: 12345.67
    MSE for Afghanistan - Asses: 23456.78
    <matplotlib plot>

    This function ensures that the model is evaluated on separate training and testing sets to provide a proper
    assessment of its performance.
    """
    # Split the data into training and testing sets based on the test_start_year
    train_data = df[df['Year'] < test_start_year]
    # Filter the data for the specified country and animal type
    test_data = df[(df['Area'] == country) & (df['Item'] == animal_type) & (df['Year'] >= test_start_year)]
    if test_data.empty:
        print(f"No test data available for {country} - {animal_type}")
        return None


    # Fit the model on the training data
    model = fit_arima_model(train_data, country, animal_type)

    if model is None:
        print(f"Not enough data for modeling {country} - {animal_type}")
        return None

    # Make predictions on the test data
    predictions, conf_int = model.predict(n_periods=len(test_data), return_conf_int=True, alpha=1-confidence_level)
    #predictions.index = test_data['Year']  # Set the index to match the years in the test data

    # Calculate error metrics
    mae = mean_absolute_error(test_data['Value'], predictions)
    mse = mean_squared_error(test_data['Value'], predictions)

    # Calculate the proportion of actual values within the confidence intervals
    proportion_in_ci = calculate_percentage_within_ci(test_data['Value'], conf_int)
    

    return mae, mse, test_data['Value'],test_data['Year'], predictions, conf_int, proportion_in_ci

# %% [markdown]
# #### 2.1.2 ARIMA model evaluation

# %%
def calculate_percentage_within_ci(test_data, conf_int):
    """
    Calculate the proportion of actual values that fall within the confidence intervals.

    Parameters:
    -----------
    test_data : array-like
        Array of actual values.
    conf_int : array-like
        Array of confidence intervals.

    Returns:
    --------
    float
        Proportion of actual values within the confidence intervals.
    """
    lower_bounds = conf_int[:, 0]
    upper_bounds = conf_int[:, 1]
    within_ci = np.sum((test_data >= lower_bounds) & (test_data <= upper_bounds))
    proportion_in_ci = within_ci / len(test_data)
    return proportion_in_ci

# %%
# Define the number of combinations to select
num_combinations = 10

# Randomly select a subset of country-animal combinations
# Get unique combinations of animal types and countries from the DataFrame
unique_combinations = df[['Area', 'Item']].drop_duplicates()
# Randomly select a subset of unique country-animal combinations
random_combinations = unique_combinations.sample(num_combinations, replace=False, random_state=123)

#ramdom_combinations = [('Thailand', 'Sheep'),
# ('Kenya', 'Goats')]
# Evaluate the models
test_start_year = 2010  # Specify the year to start testing
evaluation_results = {}

for index, row in random_combinations.iterrows():
    country = row['Area']
    animal_type = row['Item']
    results = evaluate_model(df, country, animal_type, test_start_year)
    if results is not None:
        mae, mse, test_value, test_year, predictions, conf_int, proportion_in_ci = results
        evaluation_results[(country, animal_type)] = (proportion_in_ci)
            
        # Filter the DataFrame for the specific country and animal type combination
        filtered_df = df[(df['Area'] == country) & (df['Item'] == animal_type)]
        # Plot actual vs. predicted values
        plt.figure(figsize=(8, 4))
        plt.plot(filtered_df['Year'], filtered_df['Value'], label='Actual Data')
        plt.plot(test_year, predictions, label='Predicted Data')
        # Plot confidence intervals
        plt.fill_between(test_year, conf_int[:, 0], conf_int[:, 1], color='gray', alpha=0.2, label='Confidence Interval')
        
        plt.xlabel('Year')
        plt.ylabel('Population')
        plt.title(f'ARIMA Forecast for {country} - {animal_type}')
        plt.legend()
        plt.grid(True)
        plt.show()
# Out:
# C:\Users\egh22\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\egh22\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\egh22\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# No test data available for French Guiana - Cattle
# C:\Users\egh22\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\egh22\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\egh22\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\egh22\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\egh22\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\egh22\AppData\Roaming\Python\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %% [markdown]
# <b> Results of the ARIMA model on a subset test-data </b>

# %%
#Model evaluation
evaluation_df = pd.DataFrame.from_dict(evaluation_results, orient='index', columns=['Percencentage within CI'])
evaluation_df
# Out:
#                                             Percencentage within CI
# (Bulgaria, Sheep)                                          1.000000
# (Morocco, Swine / pigs)                                    1.000000
# (Bahrain, Cattle)                                          0.923077
# (Guatemala, Swine / pigs)                                  1.000000
# (Israel, Camels)                                           1.000000
# (Burkina Faso, Cattle)                                     1.000000
# (Mongolia, Goats)                                          0.846154
# (Poland, Swine / pigs)                                     0.384615
# (Lao People's Democratic Republic, Horses)                 1.000000

# %% [markdown]
# #### 2.1.3 Forecasting values

# %%
arima_models = {}

for country in countries:
    for animal_type in animal_types:
        # Fit ARIMA model for the current combination of country and animal type
        arima_model = fit_arima_model(df, country, animal_type)
        
        # Check if the model is successfully fitted
        if arima_model is not None:
            # Store the fitted ARIMA model in the dictionary
            arima_models[(country, animal_type)] = arima_model

# %%
# Fit ARIMA models for each combination of country and animal type
forecast_results = {}
#number of years we want to forecast
num_periods = 10
for country in countries:
    for animal_type in animal_types:
        # Retrieve the ARIMA model for the current country and animal type combination
        arima_model = arima_models.get((country, animal_type))
        
        # Check if the model exists for the current combination
        if arima_model is not None:
            # Specify the number of periods into the future for which you want to forecast
            num_periods = num_periods # For example, forecast the next 5 years
            
            # Use the ARIMA model to forecast future predictions
            forecast_values = arima_model.predict(n_periods=num_periods)
            
            # Store the forecast values for the current combination
            forecast_results[(country, animal_type)] = forecast_values
